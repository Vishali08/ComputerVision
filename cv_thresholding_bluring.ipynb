# %%
import numpy as np 
import cv2
import matplotlib.pyplot as plt

# %%
image = r"C:\Users\visha\Downloads\00-puppy.jpg"
img = cv2.imread(image,0)

# %%
plt.imshow(img,cmap="gray")

# %%
res,thresh1 = cv2.threshold(img,127,255,cv2.THRESH_BINARY)

# %%
res
# Out:
# 127.0

# %%
res,threshold = cv2.threshold(img,0,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU)

# %%
plt.imshow(threshold,cmap="gray")

# %%
res,threshold3 = cv2.threshold(img,0,255,cv2.THRESH_TRUNC+cv2.THRESH_OTSU)
plt.imshow(threshold3,cmap="gray")

# %%
res,threshold4 = cv2.threshold(img,0,255,cv2.THRESH_TOZERO+cv2.THRESH_OTSU)
plt.imshow(threshold4,cmap="gray")

# %%
res,threshold5 = cv2.threshold(img,0,255,cv2.THRESH_TOZERO_INV+cv2.THRESH_OTSU)
plt.imshow(threshold5,cmap="gray")

# %%
res,threshold6 = cv2.threshold(img,0,255,cv2.THRESH_BINARY_INV+cv2.THRESH_OTSU)
plt.imshow(threshold6,cmap="gray")

# %% [markdown]
# ## Day 09

# %%
##day09
a=cv2.adaptiveThreshold(img,255,cv2.ADAPTIVE_THRESH_MEAN_C,cv2.THRESH_BINARY,11,8)
plt.imshow(a,cmap='gray')

import cv2
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
img=cv2.imread(r"C:\Users\visha\Downloads\00-puppy.jpg")
img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
##apply box filter for 5*5 matrix
box_filter=cv2.boxFilter(img,ddepth=-1,ksize=(5,5))
#display original and filtered imgs side by side
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.imshow(img)
plt.title("original img")
plt.subplot(1,2,2)
plt.imshow(box_filter)
plt.title("filtered img")
# Out:
# Text(0.5, 1.0, 'filtered img')

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
img=cv2.imread(r"C:\Users\visha\Downloads\00-puppy.jpg")
img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

median_filter=cv2.medianBlur(img,5)

#display original and filtered imgs side by side
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.imshow(img)
plt.title("original img")
plt.subplot(1,2,2)
plt.imshow(box_filter)
plt.title("filtered img")
# Out:
# Text(0.5, 1.0, 'filtered img')

# %%
gaussian_filter=cv2.GaussianBlur(img,(5,5),0)

#display original and filtered imgs side by side
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.imshow(img)
plt.title("original img")
plt.subplot(1,2,2)
plt.imshow(box_filter)
plt.title("filtered img")
# Out:
# Text(0.5, 1.0, 'filtered img')
